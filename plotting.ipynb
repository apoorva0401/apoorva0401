# %% [markdown]
# <a href="https://colab.research.google.com/github/apoorva0401/apoorva0401/blob/main/plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
apra_boy_num = [0, 1, 2, 3]


time = apra_boy_num

year_survived = [2014, 2015, 2016, 2017]

position = year_survived

#plt.plot(apra_boy_num, year_survived)

plt.style.use('ggplot')

plt.plot(position, time)

plt.xlabel('year')
plt.ylabel('apra boyfriends');

# %%
help(plt.style.use)

# or

#plt.style.use?
# Out:
# Help on function use in module matplotlib.style.core:
#
# use(style)
#     Use Matplotlib style settings from a style specification.
#
#     The style name of 'default' is reserved for reverting back to
#     the default style settings.
#
#     .. note::
#
#        This updates the `.rcParams` with the settings from the style.
#        `.rcParams` not defined in the style are kept.
#
#     Parameters
#     ----------
#     style : str, dict, Path or list
#
#         A style specification. Valid options are:
#
#         str
#             - One of the style names in `.style.available` (a builtin style or
#               a style installed in the user library path).
#
#             - A dotted name of the form "package.style_name"; in that case,
#               "package" should be an importable Python package name, e.g. at
#               ``/path/to/package/__init__.py``; the loaded style file is
#               ``/path/to/package/style_name.mplstyle``.  (Style files in
# ...

# %%
import pandas as pd

# %%
gdp = pd.read_csv('/content/drive/MyDrive/Python Course Operations/gapminder_gdp_asia.csv',index_col='country')

# %%
list(gdp.index)
# Out:
# ['Afghanistan',
#  'Bahrain',
#  'Bangladesh',
#  'Cambodia',
#  'China',
#  'Hong Kong China',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Israel',
#  'Japan',
#  'Jordan',
#  'Korea Dem. Rep.',
#  'Korea Rep.',
#  'Kuwait',
#  'Lebanon',
#  'Malaysia',
#  'Mongolia',
#  'Myanmar',
#  'Nepal',
#  'Oman',
#  'Pakistan',
#  'Philippines',
#  'Saudi Arabia',
#  'Singapore',
#  'Sri Lanka',
#  'Syria',
#  'Taiwan',
#  'Thailand',
#  'Vietnam',
#  'West Bank and Gaza',
#  'Yemen Rep.']

# %%
gdp
# Out:
#                     gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Afghanistan             779.445314      820.853030      853.100710
# Bahrain                9867.084765    11635.799450    12753.275140
# Bangladesh              684.244172      661.637458      686.341554
# Cambodia                368.469286      434.038336      496.913648
# China                   400.448611      575.987001      487.674018
# Hong Kong China        3054.421209     3629.076457     4692.648272
# India                   546.565749      590.061996      658.347151
# Indonesia               749.681655      858.900271      849.289770
# Iran                   3035.326002     3290.257643     4187.329802
# Iraq                   4129.766056     6229.333562     8341.737815
# Israel                 4086.522128     5385.278451     7105.630706
# Japan                  3216.956347     4317.694365     6576.649461
# Jordan                 1546.907807     1886.080591     2348.009158
# ...

# %%
gdp.columns
# Out:
# Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#        'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#        'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#       dtype='object')

# %%
gdp.columns = gdp.columns.str.replace('gdpPercap_','').astype(int)
#gdp.columns = years


# this could be avoided
#years

# %%
# allow automatically
x = 10
x = x+2

print(x)
# Out:
# 12

# %%
gdp
# Out:
#                              1952           1957          1962          1967  \
# country
# Afghanistan            779.445314     820.853030    853.100710    836.197138
# Bahrain               9867.084765   11635.799450  12753.275140  14804.672700
# Bangladesh             684.244172     661.637458    686.341554    721.186086
# Cambodia               368.469286     434.038336    496.913648    523.432314
# China                  400.448611     575.987001    487.674018    612.705693
# Hong Kong China       3054.421209    3629.076457   4692.648272   6197.962814
# India                  546.565749     590.061996    658.347151    700.770611
# Indonesia              749.681655     858.900271    849.289770    762.431772
# Iran                  3035.326002    3290.257643   4187.329802   5906.731805
# Iraq                  4129.766056    6229.333562   8341.737815   8931.459811
# Israel                4086.522128    5385.278451   7105.630706   8393.741404
# ...

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, Afghanistan to Yemen Rep.
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1952    33 non-null     float64
#  1   1957    33 non-null     float64
#  2   1962    33 non-null     float64
#  3   1967    33 non-null     float64
#  4   1972    33 non-null     float64
#  5   1977    33 non-null     float64
#  6   1982    33 non-null     float64
#  7   1987    33 non-null     float64
#  8   1992    33 non-null     float64
#  9   1997    33 non-null     float64
#  10  2002    33 non-null     float64
#  11  2007    33 non-null     float64
# dtypes: float64(12)
# memory usage: 3.4+ KB

# %%
# x = gdp['gdpPercap_2007']

# y = gdp['country']

# #filtering the x axis

# plt.plot(x, y)

# plt.xlabel('2007')
# plt.ylabel('india');

# %%
# x = gdp['gdpPercap_2007']

# y = gdp['gdpPercap_2007']



# plt.plot(x, y)

# plt.xlabel('2007')
# plt.ylabel('india');

# %%
# definition

gdp = gdp.transpose() # why time in row

# %%
gdp.head(5)
# Out:
# country  Afghanistan       Bahrain  Bangladesh    Cambodia       China  \
# 1952      779.445314   9867.084765  684.244172  368.469286  400.448611
# 1957      820.853030  11635.799450  661.637458  434.038336  575.987001
# 1962      853.100710  12753.275140  686.341554  496.913648  487.674018
# 1967      836.197138  14804.672700  721.186086  523.432314  612.705693
# 1972      739.981106  18268.658390  630.233627  421.624026  676.900092
#
# country  Hong Kong China       India    Indonesia         Iran         Iraq  \
# 1952         3054.421209  546.565749   749.681655  3035.326002  4129.766056
# 1957         3629.076457  590.061996   858.900271  3290.257643  6229.333562
# 1962         4692.648272  658.347151   849.289770  4187.329802  8341.737815
# 1967         6197.962814  700.770611   762.431772  5906.731805  8931.459811
# 1972         8315.928145  724.032527  1111.107907  9613.818607  9576.037596
#
# country  ...  Philippines  Saudi Arabia    Singapore    Sri Lanka  \
# ...

# %%
gdp_broke = gdp > 800

gdp_broke
# Out:
# country  Afghanistan  Bahrain  Bangladesh  Cambodia  China  Hong Kong China  \
# 1952           False     True       False     False  False             True
# 1957            True     True       False     False  False             True
# 1962            True     True       False     False  False             True
# 1967            True     True       False     False  False             True
# 1972           False     True       False     False  False             True
# 1977           False     True       False     False  False             True
# 1982            True     True       False     False   True             True
# 1987            True     True       False     False   True             True
# 1992           False     True        True     False   True             True
# 1997           False     True        True     False   True             True
# 2002           False     True        True      True   True             True
# ...

# %%
gdp[gdp_broke].plot();

# %%
#gdp.plot(); # filter and plot being able to select something and annotate it

#gdp.loc[gdp['Singapore']].plot()
#singapore = gdp.loc[:,'Singapore']
#gdp.loc[:,(gdp['Singapore']>40000)].plot();

# %%
gdp_singapore = gdp.loc[:,gdp['Singapore'] >40000]
gdp_singapore.plot()
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-100-aee7d59283bf> in <cell line: 1>()
# ----> 1 gdp_singapore = gdp.loc[:,gdp['Singapore'] >40000]
#       2 gdp_singapore.plot()
#       3
#       4
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1095             if self._is_scalar_access(key):
#    1096                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097             return self._getitem_tuple(key)
#    1098         else:
#    1099             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1287             return self._multi_take(tup)
#    1288
# -> 1289         return self._getitem_tuple_same_dim(tup)
#    1290
#    1291     def _get_label(self, label, axis: AxisInt):
#
# ...

# %%
# Filter rows where Singapore's GDP exceeds 40,000
gdp_singapore_india = gdp[gdp['Singapore','India'] > 40000]

# Now plot the filtered DataFrame
gdp_singapore_india.plot(style='.');
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Singapore', 'India')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Filter the DataFrame to only include rows where the 'Singapore' column has values greater than 40,000
gdp_singapore_india = gdp[gdp['Singapore'] > 40000]['Singapore','India']

# Now plot the filtered 'Singapore' data
gdp_singapore_india.plot(style='.');
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Singapore', 'India')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
gdp[gdp_broke].plot()
# Out:
# <Axes: >

# %%
gdp.T.India.plot()
plt.annonate()
plt.annotate('nda sarkar aayi thi',(2001,1850),
xytext=(2001, 1850), arrowprops=dict(facecolor='black', shrink=0.05));
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-381301b492ee> in <cell line: 1>()
# ----> 1 gdp.T.India.plot()
#       2 plt.annonate()
#       3 plt.annotate('nda sarkar aayi thi',(2001,1850),
#       4 xytext=(2001, 1850), arrowprops=dict(facecolor='black', shrink=0.05));
#
# NameError: name 'gdp' is not defined

# %%
import matplotlib.pyplot as plt
plt.annotate('nda sarkar aayi thi', (2018),
             xytext=(2018),
             arrowprops=dict(facecolor='black', edgecolor='blue',
                             arrowstyle='->', shrink=0.05, alpha=0.6),
             fontsize=12, color='green', fontweight='bold')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-2c79c68b0fbc> in <cell line: 2>()
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.annotate('nda sarkar aayi thi', (2018),
#       3              xytext=(2018),
#       4              arrowprops=dict(facecolor='black', edgecolor='blue',
#       5                              arrowstyle='->', shrink=0.05, alpha=0.6),
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in annotate(text, xy, xytext, xycoords, textcoords, arrowprops, annotation_clip, **kwargs)
#    2378         text, xy, xytext=None, xycoords='data', textcoords=None,
#    2379         arrowprops=None, annotation_clip=None, **kwargs):
# -> 2380     return gca().annotate(
#    2381         text, xy, xytext=xytext, xycoords=xycoords,
#    2382         textcoords=textcoords, arrowprops=arrowprops,
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

import matplotlib.animation as animation

# Fixing random state for reproducibility
np.random.seed(19680801)


def random_walk(num_steps, max_step=0.05):
    """Return a 3D random walk as (num_steps, 3) array."""
    start_pos = np.random.random(3)
    steps = np.random.uniform(-max_step, max_step, size=(num_steps, 3))
    walk = start_pos + np.cumsum(steps, axis=0)
    return walk


def update_lines(num, walks, lines):
    for line, walk in zip(lines, walks):
        # NOTE: there is no .set_data() for 3 dim data...
        line.set_data(walk[:num, :2].T)
        line.set_3d_properties(walk[:num, 2])
    return lines


# Data: 40 random walks as (num_steps, 3) arrays
num_steps = 30
walks = [random_walk(num_steps) for index in range(40)]


# Attaching 3D axis to the figure
fig = plt.figure()
ax = fig.add_subplot(projection="3d")

# Create lines initially without data
lines = [ax.plot([], [], [])[0] for _ in walks]

# Setting the axes properties
ax.set(xlim3d=(0, 1), xlabel='X')
ax.set(ylim3d=(0, 1), ylabel='Y')
ax.set(zlim3d=(0, 1), zlabel='Z')

# Creating the Animation object
ani = animation.FuncAnimation(
    fig, update_lines, num_steps, fargs=(walks, lines), interval=100)
plt.style.use('seaborn-v0_8-dark')
plt.show();

# %%
x= 10

x == x+2 # shu=ould we use alias for this or not

# %%
x

# %%
a = 5
b = a
b

# %%
a = 5
b = 0
a == b
b

# %%
a = 5

a == 5

# %%
x = 5
y = 7
#z=0
z = x*y

z

# %%
gdp.head(5)

# %%
# different symbole for india and singa

#gdp.loc[:,[gdp['Singapore']>40000][['India','Singapore']]]

gdp[gdp['Singapore'] > 40000][['India', 'Singapore']].plot(style='s')

#.plot(style='.')

#.plot()

# %%
gdp[['India', 'Singapore']].plot(style='s')

# %%
# after 2000 filter on index
#gdp.index

gdp[(gdp.index > 2000)][['India', 'Singapore']].plot()

# %%
original = "tin"
result = ""
for char in original:
    result = char + result
print(result)

# %%
# Set the index to 'Year' if it's not already
#gdp.set_index('Year', inplace=True)

# Filter the DataFrame for years after 2000 and 'Singapore' greater than 40,000
filtered_gdp = gdp[(gdp.index > 2000) & (gdp['Singapore'] > 40000)][['India', 'Singapore']]

# Plot the filtered data with square markers
filtered_gdp.plot(style='s')
# Out:
# <Axes: >

# %%
# Set the index to 'Year' if it's not already
#gdp.set_index('Year', inplace=True)

# Filter the DataFrame for years after 2000 and 'Singapore' greater than 40,000
filtered_gdp = gdp[(gdp['Singapore'] > 40000)][['India', 'Singapore','Afghanistan']]

# (gdp.index > 2000) &

# Plot the filtered data with square markers
filtered_gdp.plot(style='s')
# Out:
# <Axes: >

# %%
#find a ctrl  z

filtered_gdp
# Out:
# country  Afghanistan      Bahrain   Bangladesh     Cambodia        China  \
# 2007      974.580338  29796.04834  1391.253792  1713.778686  4959.114854
#
# country  Hong Kong China        India    Indonesia         Iran         Iraq  \
# 2007         39724.97867  2452.210407  3540.651564  11605.71449  4471.061906
#
# country  ...  Philippines  Saudi Arabia    Singapore    Sri Lanka  \
# 2007     ...  3190.481016   21654.83194  47143.17964  3970.095407
#
# country        Syria       Taiwan     Thailand      Vietnam  \
# 2007     4184.548089  28718.27684  7458.396327  2441.576404
#
# country  West Bank and Gaza   Yemen Rep.
# 2007            3025.349798  2280.769906
#
# [1 rows x 33 columns]

# %%
plt.figure(figsize=(100,100))
gdp.plot(kind='box',rot=45);

# %%
plt.figure(figsize=(100,100))
gdp.T.plot(kind='box',rot=45);

# %%
#plt.figure(figsize=(100,100))
gdp['Saudi Arabia'].plot(kind='box');

# %%
#plt.figure(figsize=(100,100))
gdp.plot(x=gdp['Afghanistan'],y=gdp[['India', 'Singapore']], kind='scatter');
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-135-b4a221c3d67b> in <cell line: 2>()
#       1 #plt.figure(figsize=(100,100))
# ----> 2 gdp.plot(x=gdp['Afghanistan'],y=gdp[['India', 'Singapore']], kind='scatter');
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     918         if kind in self._dataframe_kinds:
#     919             if isinstance(data, ABCDataFrame):
# --> 920                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     921             else:
#     922                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ...

# %%
gdp.head(5)
# Out:
# country  Afghanistan       Bahrain  Bangladesh    Cambodia       China  \
# 1952      779.445314   9867.084765  684.244172  368.469286  400.448611
# 1957      820.853030  11635.799450  661.637458  434.038336  575.987001
# 1962      853.100710  12753.275140  686.341554  496.913648  487.674018
# 1967      836.197138  14804.672700  721.186086  523.432314  612.705693
# 1972      739.981106  18268.658390  630.233627  421.624026  676.900092
#
# country  Hong Kong China       India    Indonesia         Iran         Iraq  \
# 1952         3054.421209  546.565749   749.681655  3035.326002  4129.766056
# 1957         3629.076457  590.061996   858.900271  3290.257643  6229.333562
# 1962         4692.648272  658.347151   849.289770  4187.329802  8341.737815
# 1967         6197.962814  700.770611   762.431772  5906.731805  8931.459811
# 1972         8315.928145  724.032527  1111.107907  9613.818607  9576.037596
#
# country  ...  Philippines  Saudi Arabia    Singapore    Sri Lanka  \
# ...

# %%
plt.scatter(gdp.index, gdp['India'])
# Adding labels and title
plt.xlabel('Year')
plt.ylabel('GDP')
plt.title('GDP over Time')
plt.legend();
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
